# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data/supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby("Branch")["gross income"].sum().sort_values(ascending=False)
# Out:
# Branch
# C    5265.1765
# A    5057.1605
# B    5057.0320
# Name: gross income, dtype: float64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
city = (df.groupby(["Branch", "City"]).agg(profit=("gross income", "sum")).sort_values("profit", ascending=False))
city
# Out:
#                      profit
# Branch City
# C      Naypyitaw  5265.1765
# A      Yangon     5057.1605
# B      Mandalay   5057.0320

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table(df, index="Branch", columns="Product line", values="Invoice ID", aggfunc="count")
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category["Electronic accessories"].idxmax()
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# 1. Чи є різниця середнього чеку по категоріям в залежності від статі?

# %%
avg_spending_by_gender = (df.groupby(["Gender", "Product line"])["Total"].mean().sort_values(ascending=False))

avg_spending_by_gender
# Out:
# Gender  Product line
# Female  Home and lifestyle        380.213639
#         Food and beverages        368.565750
# Male    Health and beauty         348.099460
#         Sports and travel         340.360327
# Female  Sports and travel         324.712739
#         Electronic accessories    322.643125
#         Fashion accessories       317.056250
# Male    Electronic accessories    316.691965
#         Home and lifestyle        294.136241
#         Fashion accessories       291.079207
# Female  Health and beauty         290.015414
# Male    Food and beverages        273.499125
# Name: Total, dtype: float64

# %% [markdown]
# Жінки мають вищий середній чек у більшості категорій
#
# Особливо у:
# Home and lifestyle
# Food and beverages
#
# Чоловіки більше витрачають на:
# Health and beauty
# Sports and travel
#
# Рекомендації:
# Робити набори для товарів з високим попитом, щоб збільшити їх продаж
# Запускати програми лояльності саме в цих категоріях

# %% [markdown]
# 2. Чи впливає тип клієнта (Member / Normal) на прибуток магазину?

# %%
member_analysis = (df.groupby("Customer type")["Total"].agg(["count", "mean", "sum"]).sort_values("sum", ascending=False))

member_analysis
# Out:
#                count        mean         sum
# Customer type
# Member           501  327.791305  164223.444
# Normal           499  318.122856  158743.305

# %% [markdown]
# Members здійснюють трохи більше покупок, мають вищий середній чек та більший сумарний виторг
#
# Учасники програми лояльності приносять більше доходу.
#
# Рекомендації: розвивати програму лояльності та залучати до неї інших клієнтів (н-д: бонус за першу покупку, знижка і т.д.). Також розвивати пропозиції вже для учасників програми: персональні знижки та бонуси також.

# %% [markdown]
# 3. У які години які категорії товарів приносять найбільший прибуток?

# %%
time = '13:00'
def get_hour(time):
    return int(time[:2])
df['Hour'] = df['Time'].apply(lambda x: get_hour(x))
pivot_profit = pd.pivot_table(df, index="Hour", columns="Product line", values="gross income", aggfunc="sum")

pivot_profit
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Hour
# 10                          200.8460             290.6020            230.6590
# 11                          283.3420             208.0240            305.5575
# 12                          163.9545             235.7610            205.2810
# 13                          184.6250             386.1615            178.4690
# 14                          271.1225             225.9605            203.0125
# 15                          274.1240             164.6030            353.2475
# 16                          165.0605             264.0665            217.2660
# 17                          195.8055             196.1105             67.6830
# 18                          307.0085             212.4755            199.9305
# 19                          275.1025             292.2455            380.0705
# 20                          266.5105             109.9850            332.3875
#
# ...

# %% [markdown]
# Обідні години - продажі їжі та товарів для дому.
# Вечір (особливо 19:00) - найприбутковіший період, із фокусом на спорт, електроніку та аксесуари.
#
# Рекомендації:
# Ввечері просувати товари, що пов'язані з електронікою та спортом. Також варто по іншим категоріям зробити акції, набори, додаткові бонуси за покупки.
# В обід більше прибутку приносить їжа, тому тут можемо робити набори (комплексні обіди), додаткові акції на їжу та знижки.
#
# Також в залежності від часу можемо робити ті чи інші викладки товару, залежності від продажів та таргетовану рекламу по часу.
